# %%
import numpy as np
import matplotlib.pyplot as plt
import os

NOME = "moreira"

mydir = "/home/feulo/pd-externals/mindflex/teste_attention/" + NOME
if(os.path.isfile(mydir+"/test_0_err.txt")):
    err0 = np.loadtxt(mydir+"/test_0_err.txt")
else:
    err0 = np.zeros(8)
if(os.path.isfile(mydir+"/test_1_err.txt")):
    err1 = np.loadtxt(mydir+"/test_1_err.txt")
else:
    err1 = np.zeros(8)
if(os.path.isfile(mydir+"/test_2_err.txt")):
    err2 = np.loadtxt(mydir+"/test_2_err.txt")
else:
    err2 = np.zeros(8)   
if(os.path.isfile(mydir+"/times.txt")):
    times = np.loadtxt(mydir+"/times.txt")
else:
    times = np.zeros(3)
if(os.path.isfile(mydir+"/threshold.txt")):
    threshold = np.loadtxt(mydir+"/threshold.txt")
else:
    threshold = np.zeros(1)

# %% [markdown]
# # RELATÓRIO DO USUÁRIO
#
# ## Primeiro Teste
#
# <img src="scores/score_1_gif.gif" width="500">
# #### Tempo = {{format(times[0], '.3f')}} segundos
# #### Erros
#
# Item 1  | Item 2 | Item 3 | Item 4 | Item 5 | Item 6 | Item 7 | Item 8 | ** TOTAL **
# :------:|:------:|:------:|:------:|:------:|:------:|:------:|:------:|:-----------:
# {{int(err0[0])}} | {{int(err0[1])}} | {{int(err0[2])}} | {{int(err0[3])}} |{{int(err0[4])}} | {{int(err0[5])}} | {{int(err0[6])}} | {{int(err0[7])}} | ** {{int(err0.sum())}} **
#
# ### Nível medio de atenção quando concentrado = {{float(threshold)}}
#
# --------

# %%
if(os.path.isfile(mydir+"/test_0_attention_interface.txt")):
    att =  np.loadtxt(mydir+"/test_0_attention_interface.txt")
if(os.path.isfile(mydir+"/test_0_blink.txt")):
    blk =  np.loadtxt(mydir+"/test_0_blink.txt")
plt.plot(att,label='Attention')
for i in range(blk.size):
    if blk[i] != 0:
        plt.axvline(i, color='black',ls='--')
plt.axvline(color='black',ls='--',label='Blink')
plt.axhline(75, color='red',label='Attention Threshold')
#plt.axis([0,60,0,100])                                                              
plt.grid()
plt.xlabel('Time [seconds]')
plt.ylabel('Attention level')
plt.title('Mindflex Attetion Level X Time')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
blk.size
# Out:
# 70

# %% [markdown]
# ## Segundo Teste
# <img src="scores/score_2_gif.gif" width="500">
# #### Tempo = {{format(times[1], '.3f')}} segundos
# #### Erros
#
# Item 1  | Item 2 | Item 3 | Item 4 | Item 5 | Item 6 | Item 7 | Item 8 | ** TOTAL **
# :------:|:------:|:------:|:------:|:------:|:------:|:------:|:------:|:-----------:
# {{int(err1[0])}} | {{int(err1[1])}} | {{int(err1[2])}} | {{int(err1[3])}} |{{int(err1[4])}} | {{int(err1[5])}} | {{int(err1[6])}} | {{int(err1[7])}} | ** {{int(err1.sum())}} **
#
# -------

# %%
if(os.path.isfile(mydir+"/test_1_attention_interface.txt")):
    att =  np.loadtxt(mydir+"/test_1_attention_interface.txt")
if(os.path.isfile(mydir+"/test_1_blink.txt")):
    blk =  np.loadtxt(mydir+"/test_1_blink.txt")
plt.plot(att,label='Attention')
for i in range(blk.size):
    if blk[i] != 0:
        plt.axvline(i, color='black',ls='--')
plt.axvline(color='black',ls='--',label='Blink')
plt.axhline(threshold, color='red',label='Attention Threshold')
#plt.axis([0,60,0,100])                                                              
plt.grid()
plt.xlabel('Time [seconds]')
plt.ylabel('Attention level')
plt.title('Mindflex Attetion Level X Time')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
blk.size
# Out:
# 85

# %% [markdown]
# ## Terceiro Teste
#
# <img src="scores/score_3_gif.gif" width="500">
# #### Tempo = {{format(times[2], '.3f')}} segundos
# #### Erros
#
# Item 1  | Item 2 | Item 3 | Item 4 | Item 5 | Item 6 | Item 7 | Item 8 | ** TOTAL **
# :------:|:------:|:------:|:------:|:------:|:------:|:------:|:------:|:-----------:
# {{int(err2[0])}} | {{int(err2[1])}} | {{int(err2[2])}} | {{int(err2[3])}} |{{int(err2[4])}} | {{int(err2[5])}} | {{int(err2[6])}} | {{int(err2[7])}} | ** {{int(err2.sum())}} **

# %%
if(os.path.isfile(mydir+"/test_2_attention_interface.txt")):
    att =  np.loadtxt(mydir+"/test_2_attention_interface.txt")
if(os.path.isfile(mydir+"/test_2_blink.txt")):
    blk =  np.loadtxt(mydir+"/test_2_blink.txt")
plt.plot(att,label='Attention')
for i in range(blk.size):
    if blk[i] != 0:
        plt.axvline(i, color='black',ls='--')
plt.axvline(color='black',ls='--',label='Blink')
plt.axhline(threshold, color='red',label='Attention Threshold')
#plt.axis([0,60,0,100])                                                              
plt.grid()
plt.xlabel('Time [seconds]')
plt.ylabel('Attention level')
plt.title('Mindflex Attetion Level X Time')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
blk.size
# Out:
# 44
